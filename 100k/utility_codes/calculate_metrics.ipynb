# %%
import os
import math
import numpy as np
import torch
from tqdm import tqdm
from transformers import AutoTokenizer, AutoModelForMaskedLM

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model_name = "microsoft/codebert-base-mlm"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForMaskedLM.from_pretrained(model_name).to(device)
model.eval()
# Out:
# Some weights of the model checkpoint at microsoft/codebert-base-mlm were not used when initializing RobertaForMaskedLM: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# RobertaForMaskedLM(
#   (roberta): RobertaModel(
#     (embeddings): RobertaEmbeddings(
#       (word_embeddings): Embedding(50265, 768, padding_idx=1)
#       (position_embeddings): Embedding(514, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): RobertaEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSdpaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (lm_head): RobertaLMHead(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (decoder): Linear(in_features=768, out_features=50265, bias=True)
#   )
# )

# %%
def load_text_data(folder):
    texts, labels = [], []

    for label_name, label in [("Label_0", 0), ("Label_1", 1)]:
        subfolder = os.path.join(folder, label_name)

        for file in sorted(os.listdir(subfolder)):
            if file.endswith(".txt"):
                with open(os.path.join(subfolder, file), "r", encoding="utf-8") as f:
                    texts.append(f.read())
                labels.append(label)

    return texts, np.array(labels)

# %%
def compute_metrics(text, max_len=256):
    inputs = tokenizer(
        text,
        return_tensors="pt",
        truncation=True,
        max_length=max_len
    )

    input_ids = inputs["input_ids"].to(device)
    seq_len = input_ids.size(1)

    logits_list = []
    target_ids = []

    # Mask each token (skip special tokens)
    for i in range(1, seq_len - 1):
        masked = input_ids.clone()
        masked[0, i] = tokenizer.mask_token_id

        with torch.no_grad():
            outputs = model(masked)

        logits = outputs.logits[0, i].detach().cpu()  # 🔥 move to CPU
        logits_list.append(logits)

        target_ids.append(input_ids[0, i].detach().cpu())

    # Stack once (efficient)
    logits_tensor = torch.stack(logits_list)   # [T, V]
    targets = torch.tensor(target_ids)         # [T]

    # =========================
    # Compute metrics
    # =========================

    probs = torch.softmax(logits_tensor, dim=-1)
    log_probs = torch.log(probs)

    # (1) Log-Rank
    sorted_ids = torch.argsort(logits_tensor, dim=-1, descending=True)
    ranks = (sorted_ids == targets.unsqueeze(1)).nonzero()[:, 1] + 1
    log_rank = torch.log(ranks.float()).mean().item()

    # (2) Entropy
    entropy = (-(probs * log_probs).sum(dim=-1)).mean().item()

    # (3–5) GLTR Top-k ratios
    t = targets.unsqueeze(1)

    top10 = torch.topk(logits_tensor, 10, dim=-1).indices
    top100 = torch.topk(logits_tensor, 100, dim=-1).indices
    top1000 = torch.topk(logits_tensor, 1000, dim=-1).indices

    top10_ratio = (top10 == t).any(dim=1).float().mean().item()
    top100_ratio = (top100 == t).any(dim=1).float().mean().item()
    top1000_ratio = (top1000 == t).any(dim=1).float().mean().item()

    # 🔥 free memory
    del logits_tensor, probs, log_probs
    torch.cuda.empty_cache()

    return [
        log_rank,
        entropy,
        top10_ratio,
        top100_ratio,
        top1000_ratio
    ]

# %%
def compute_dataset(texts, name="Dataset"):
    results = []

    for text in tqdm(texts, desc=f"Metrics ({name})"):
        results.append(compute_metrics(text))  # your optimized function

    return np.array(results)

# %%
DATASET_PATH = "../text_files/train_split"   # 🔥 CHANGE THIS
texts, labels = load_text_data(DATASET_PATH)
metrics = compute_dataset(texts, "New Dataset")

np.savez(
    "metrics_train.npz",
    metrics=metrics,
    labels=labels
)
# Out:
# Metrics (New Dataset):   0%|          | 0/5264 [00:00<?, ?it/s]
# Metrics (New Dataset):   0%|          | 21/5264 [01:16<5:16:38,  3.62s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 DATASET_PATH = "../text_files/train_split"   # 🔥 CHANGE THIS
#       2 texts, labels = load_text_data(DATASET_PATH)
# ----> 3 metrics = compute_dataset(texts, "New Dataset")
#       5 np.savez(
#       6     "metrics_train.npz",
#       7     metrics=metrics,
#       8     labels=labels
#       9 )
#
# Cell In[6], line 5, in compute_dataset(texts, name)
#       2 results = []
#       4 for text in tqdm(texts, desc=f"Metrics ({name})"):
# ----> 5     results.append(compute_metrics(text))  # your optimized function
#       7 return np.array(results)
#
# Cell In[5], line 21, in compute_metrics(text, max_len)
#      18 masked[0, i] = tokenizer.mask_token_id
#      20 with torch.no_grad():
# ---> 21     outputs = model(masked)
#      23 logits = outputs.logits[0, i].detach().cpu()  # 🔥 move to CPU
#      24 logits_list.append(logits)
#
# File ~/BTP/venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/BTP/venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/BTP/venv/lib/python3.12/site-packages/transformers/models/roberta/modeling_roberta.py:1073, in RobertaForMaskedLM.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, labels, output_attentions, output_hidden_states, return_dict)
#    1056 r"""
#    1057 token_type_ids (`torch.LongTensor` of shape `(batch_size, sequence_length)`, *optional*):
#    1058     Segment token indices to indicate first and second portions of the inputs. Indices are selected in `[0,1]`:
#    (...)   1069     loss is only computed for the tokens with labels in `[0, ..., config.vocab_size]`
#    1070 """
#    1071 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1073 outputs = self.roberta(
#    1074     input_ids,
#    1075     attention_mask=attention_mask,
#    1076     token_type_ids=token_type_ids,
#    1077     position_ids=position_ids,
#    1078     head_mask=head_mask,
#    1079     inputs_embeds=inputs_embeds,
#    1080     encoder_hidden_states=encoder_hidden_states,
#    1081     encoder_attention_mask=encoder_attention_mask,
#    1082     output_attentions=output_attentions,
#    1083     output_hidden_states=output_hidden_states,
#    1084     return_dict=return_dict,
#    1085 )
#    1086 sequence_output = outputs[0]
#    1087 prediction_scores = self.lm_head(sequence_output)
#
# File ~/BTP/venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/BTP/venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/BTP/venv/lib/python3.12/site-packages/transformers/models/roberta/modeling_roberta.py:772, in RobertaModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#     770     raise ValueError("You cannot specify both input_ids and inputs_embeds at the same time")
#     771 elif input_ids is not None:
# --> 772     self.warn_if_padding_and_no_attention_mask(input_ids, attention_mask)
#     773     input_shape = input_ids.size()
#     774 elif inputs_embeds is not None:
#
# File ~/BTP/venv/lib/python3.12/site-packages/transformers/modeling_utils.py:5702, in PreTrainedModel.warn_if_padding_and_no_attention_mask(self, input_ids, attention_mask)
#    5699     return
#    5701 # Check only the first and last input IDs to reduce overhead.
# -> 5702 if self.config.pad_token_id in input_ids[:, [-1, 0]]:
#    5703     warn_string = (
#    5704         "We strongly recommend passing in an `attention_mask` since your input_ids may be padded. See "
#    5705         "https://huggingface.co/docs/transformers/troubleshooting"
#    5706         "#incorrect-output-when-padding-tokens-arent-masked."
#    5707     )
#    5709     # If the pad token is equal to either BOS, EOS, or SEP, we do not know whether the user should use an
#    5710     # attention_mask or not. In this case, we should still show a warning because this is a rare case.
#
# File ~/BTP/venv/lib/python3.12/site-packages/torch/_tensor.py:1255, in Tensor.__contains__(self, element)
#    1250     return handle_torch_function(Tensor.__contains__, (self,), self, element)
#    1251 if isinstance(
#    1252     element, (torch.Tensor, Number, torch.SymInt, torch.SymFloat, torch.SymBool)
#    1253 ):
#    1254     # type hint doesn't understand the __contains__ result array
# -> 1255     return bool((element == self).any().item())  # type: ignore[union-attr]
#    1257 raise RuntimeError(
#    1258     f"Tensor.__contains__ only supports Tensor or scalar, but you passed in a {type(element)}."
#    1259 )
#
# KeyboardInterrupt:

# %%
os.getcwd()
# Out:
# '/home/info-sec-lab/BTP/100k/utility_codes'

# %%
DATASET_PATH = "../text_files/test_split"   # 🔥 CHANGE THIS
texts, labels = load_text_data(DATASET_PATH)
metrics = compute_dataset(texts, "New Dataset")

np.savez(
    "metrics_test.npz",
    metrics=metrics,
    labels=labels
)
# Out:
# Metrics (New Dataset):   0%|          | 0/2256 [00:00<?, ?it/s]
# Metrics (New Dataset): 100%|██████████| 2256/2256 [1:30:44<00:00,  2.41s/it]

# %%
os.getcwd()
# Out:
# '/home/info-sec-lab/BTP/100k/utility_codes'

# %%
import numpy as np
import numpy as np

# Load the .npz file
data = np.load('metrics_test.npz')

# List all array names (keys)
print("Keys in the file:", data.files)

# If there is only one array, use it directly
if len(data.files) == 1:
    key = data.files[0]
    arr = data[key]
    print(f"Using the only array: '{key}', shape = {arr.shape}")
    if arr.ndim >= 2:
        print(f"Number of rows: {arr.shape[0]}")
    elif arr.ndim == 1:
        print(f"1D array – number of elements (can be seen as rows): {arr.shape[0]}")
    else:
        print("Array has 0 dimensions (scalar) – no rows.")

# If there are multiple arrays, you need to decide which one to use.
# For example, pick the first array:
else:
    key = data.files[0]
    arr = data[key]
    print(f"Using first array: '{key}', shape = {arr.shape}")
    if arr.ndim >= 2:
        print(f"Number of rows: {arr.shape[0]}")
    else:
        print("First array is not 2D – interpret rows differently.")
# Out:
# Keys in the file: ['metrics', 'labels']
# Using first array: 'metrics', shape = (2256, 5)
# Number of rows: 2256
